# %% [markdown]
# # LinReg

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import csv
import re
import string

from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from scipy.stats import uniform, randint
import xgboost as xgb
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %% [markdown]
# # Test Train

# %%
df = pd.read_csv('census_clean.csv')

# %%
train = df[df['ZZ_SPLIT'] == 'train']
X_train = train.drop(columns=['ZA_TARGET','ZZ_SPLIT'])
y_train = train['ZA_TARGET']


test = df[df['ZZ_SPLIT'] == 'test']
X_test = test.drop(columns=['ZA_TARGET','ZZ_SPLIT'])
y_test = test['ZA_TARGET']

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
y_train.sum()/y_train.count()
# Out:
# 0.08077495031478882

# %% [markdown]
# ## Model Builing

# %% [markdown]
# > Logistic Regression

# %%
logR = LogisticRegression(max_iter= 10000)

param_grid_logR = {'C' : [0.001,0.01,0.1,1,10,100]}


grid_logR = GridSearchCV(estimator=logR, param_grid=param_grid_logR,cv=8)
grid_logR = grid_logR.fit(X_train,y_train)

y_pred_train_logR = grid_logR.predict(X_train)
y_pred_test_logR = grid_logR.predict(X_test)

acc_logR = accuracy_score(y_test, y_pred_test_logR)
f1_logR = f1_score(y_test, y_pred_test_logR)

print('\n----- Logistic Regression ----')
print('Accuracy :',accuracy_score(y_train, y_pred_train_logR))
print('f1 :',f1_score(y_train, y_pred_train_logR))

print('Testing')
print('Accuracy :',acc_logR)
print('f1 :',f1_logR)
# Out:
# ----- Logistic Regression ----
# Accuracy : 0.9325253985240365
# f1 : 0.4314988290398127
# Testing
# Accuracy : 0.9343109926069567
# f1 : 0.4293401965372017

# %% [markdown]
# > Random Forest

# %%
rf = RandomForestClassifier(n_jobs=14)

param_grid_rf = {'max_depth': [4,8,16],
            'n_estimators':[100,150,200],
            'max_features':['sqrt',1,5,10],
            'min_samples_split': [1,2,4]}


grid_rf = GridSearchCV(estimator=rf, param_grid=param_grid_rf,cv=8)
grid_rf = grid_rf.fit(X_train,y_train)


y_pred_train_rf = grid_rf.predict(X_train)
y_pred_test_rf = grid_rf.predict(X_test)

acc_rf = accuracy_score(y_test, y_pred_test_rf)
f1_rf = f1_score(y_test, y_pred_test_rf)

print('\n----- Random Forest ----')
print('Accuracy :',accuracy_score(y_train, y_pred_train_rf))
print('f1 :',f1_score(y_train, y_pred_train_rf))

print('Testing')
print('Accuracy :',acc_rf)
print('f1 :',f1_rf)
# Out:
# C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 288 fits failed out of a total of 864.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 288 fits failed with the following error:
# joblib.externals.loky.process_executor._RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\joblib\externals\loky\process_executor.py", line 436, in _process_worker
#     r = call_item()
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\joblib\externals\loky\process_executor.py", line 288, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\joblib\_parallel_backends.py", line 595, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\fixes.py", line 117, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\ensemble\_forest.py", line 189, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\tree\_classes.py", line 969, in fit
#     super().fit(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\tree\_classes.py", line 265, in fit
#     check_scalar(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\validation.py", line 1480, in check_scalar
#     raise ValueError(
# ValueError: min_samples_split == 1, must be >= 2.
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\ensemble\_forest.py", line 476, in fit
#     trees = Parallel(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\joblib\parallel.py", line 1056, in __call__
#     self.retrieve()
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\joblib\parallel.py", line 935, in retrieve
#     self._output.extend(job.get(timeout=self.timeout))
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\joblib\_parallel_backends.py", line 542, in wrap_future_result
#     return future.result(timeout=timeout)
#   File "c:\Program Files\Python310\lib\concurrent\futures\_base.py", line 446, in result
#     return self.__get_result()
#   File "c:\Program Files\Python310\lib\concurrent\futures\_base.py", line 391, in __get_result
#     raise self._exception
# ValueError: min_samples_split == 1, must be >= 2.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_search.py:953: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan 0.91922505 0.91922505 0.91922505
#  0.91922505 0.91922505 0.91922505        nan        nan        nan
#  0.91922505 0.91922505 0.91922505 0.91922505 0.91922505 0.91922505
#         nan        nan        nan 0.91922505 0.91922505 0.91922505
#  0.91922505 0.91922505 0.91922505        nan        nan        nan
#  0.91934318 0.91936402 0.91935013 0.91952386 0.91937098 0.91928064
#         nan        nan        nan 0.92880072 0.92871733 0.92845328
#  0.92836294 0.92867564 0.92849497        nan        nan        nan
#  0.91922505 0.91922505 0.91922505 0.91922505 0.91922505 0.91922505
#         nan        nan        nan 0.92255361 0.92260224 0.9226231
#  0.92274817 0.92246327 0.92248412        nan        nan        nan
#  0.92972493 0.92983612 0.93005849 0.92981526 0.9299751  0.92987086
#         nan        nan        nan 0.93470734 0.9346726  0.934617
#  0.93443633 0.93447107 0.93441548        nan        nan        nan
#  0.91946826 0.91953081 0.91945437 0.91939183 0.91939183 0.91937098
#         nan        nan        nan 0.93247672 0.93240028 0.93253231
#  0.93274079 0.93251841 0.9326296         nan        nan        nan
#  0.93497835 0.93511733 0.93495055 0.93483937 0.93488802 0.9349575 ]
#   warnings.warn(
# ----- Random Forest ----
# Accuracy : 0.951822717607327
# f1 : 0.6133511795214991
# Testing
# Accuracy : 0.9377045206641619
# f1 : 0.4461206896551723

# %% [markdown]
# > XGBoost

# %%
xg = xgb.XGBClassifier(booster='gblinear')

param_grid_xg = { # default 3
                "n_estimators": [100,150,200,250,300],
                "lambda": [0,0.1,1],
                "alpha": [0,0.1,1],
                "feature_selector": ['cyclic','greedy','random']}


grid_xg = GridSearchCV(estimator=xg, param_grid=param_grid_xg,cv=8)
grid_xg = grid_xg.fit(X_train,y_train)


y_pred_train_xg = grid_xg.predict(X_train)
y_pred_test_xg = grid_xg.predict(X_test)

acc_xg = accuracy_score(y_test, y_pred_test_xg)
f1_xg = f1_score(y_test, y_pred_test_xg)

print('\n----- XGBoost ----')
print('Accuracy :',accuracy_score(y_train, y_pred_train_xg))
print('f1 :',f1_score(y_train, y_pred_train_xg))

print('Testing')
print('Accuracy :',acc_xg)
print('f1 :',f1_xg)
# Out:
# C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 720 fits failed out of a total of 1080.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [00:25:10] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/linear/updater_shotgun.cc:21: Unsupported feature selector for shotgun updater.
# Supported options are: {cyclic, shuffle}
#
# --------------------------------------------------------------------------------
# 7 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [00:25:11] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/linear/updater_shotgun.cc:21: Unsupported feature selector for shotgun updater.
# Supported options are: {cyclic, shuffle}
#
# --------------------------------------------------------------------------------
# 8 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [00:25:12] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/linear/updater_shotgun.cc:21: Unsupported feature selector for shotgun updater.
# Supported options are: {cyclic, shuffle}
#
# --------------------------------------------------------------------------------
# 7 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [00:25:13] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/linear/updater_shotgun.cc:21: Unsupported feature selector for shotgun updater.
# Supported options are: {cyclic, shuffle}
#
# --------------------------------------------------------------------------------
# 8 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [00:25:14] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/linear/updater_shotgun.cc:21: Unsupported feature selector for shotgun updater.
# Supported options are: {cyclic, shuffle}
#
# --------------------------------------------------------------------------------
# 6 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [00:25:15] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/linear/updater_shotgun.cc:21: Unsupported feature selector for shotgun updater.
# Supported options are: {cyclic, shuffle}
#
# --------------------------------------------------------------------------------
# 7 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [00:25:16] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/linear/updater_shotgun.cc:21: Unsupported feature selector for shotgun updater.
# Supported options are: {cyclic, shuffle}
#
# --------------------------------------------------------------------------------
# 7 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [00:25:17] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/linear/updater_shotgun.cc:21: Unsupported feature selector for shotgun updater.
# Supported options are: {cyclic, shuffle}
#
# --------------------------------------------------------------------------------
# 7 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [00:25:18] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/linear/updater_shotgun.cc:21: Unsupported feature selector for shotgun updater.
# Supported options are: {cyclic, shuffle}
#
# --------------------------------------------------------------------------------
# 8 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [00:25:19] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/linear/updater_shotgun.cc:21: Unsupported feature selector for shotgun updater.
# Supported options are: {cyclic, shuffle}
#
# --------------------------------------------------------------------------------
# 7 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [00:25:20] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/linear/updater_shotgun.cc:21: Unsupported feature selector for shotgun updater.
# Supported options are: {cyclic, shuffle}
#
# --------------------------------------------------------------------------------
# 7 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [00:25:21] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/linear/updater_shotgun.cc:21: Unsupported feature selector for shotgun updater.
# Supported options are: {cyclic, shuffle}
#
# --------------------------------------------------------------------------------
# 7 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [00:25:22] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/linear/updater_shotgun.cc:21: Unsupported feature selector for shotgun updater.
# Supported options are: {cyclic, shuffle}
#
# --------------------------------------------------------------------------------
# 7 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [00:25:23] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/linear/updater_shotgun.cc:21: Unsupported feature selector for shotgun updater.
# Supported options are: {cyclic, shuffle}
#
# --------------------------------------------------------------------------------
# 7 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [00:25:24] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/linear/updater_shotgun.cc:21: Unsupported feature selector for shotgun updater.
# Supported options are: {cyclic, shuffle}
#
# --------------------------------------------------------------------------------
# 7 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [00:25:25] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/linear/updater_shotgun.cc:21: Unsupported feature selector for shotgun updater.
# Supported options are: {cyclic, shuffle}
#
# --------------------------------------------------------------------------------
# 7 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [00:25:26] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/linear/updater_shotgun.cc:21: Unsupported feature selector for shotgun updater.
# Supported options are: {cyclic, shuffle}
#
# --------------------------------------------------------------------------------
# 7 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [00:25:27] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/linear/updater_shotgun.cc:21: Unsupported feature selector for shotgun updater.
# Supported options are: {cyclic, shuffle}
#
# --------------------------------------------------------------------------------
# 7 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [00:25:28] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/linear/updater_shotgun.cc:21: Unsupported feature selector for shotgun updater.
# Supported options are: {cyclic, shuffle}
#
# --------------------------------------------------------------------------------
# 8 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [00:25:29] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/linear/updater_shotgun.cc:21: Unsupported feature selector for shotgun updater.
# Supported options are: {cyclic, shuffle}
#
# --------------------------------------------------------------------------------
# 7 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [00:25:30] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/linear/updater_shotgun.cc:21: Unsupported feature selector for shotgun updater.
# Supported options are: {cyclic, shuffle}
#
# --------------------------------------------------------------------------------
# 7 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [00:25:31] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/linear/updater_shotgun.cc:21: Unsupported feature selector for shotgun updater.
# Supported options are: {cyclic, shuffle}
#
# --------------------------------------------------------------------------------
# 7 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [00:25:32] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/linear/updater_shotgun.cc:21: Unsupported feature selector for shotgun updater.
# Supported options are: {cyclic, shuffle}
#
# --------------------------------------------------------------------------------
# 7 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [00:25:33] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/linear/updater_shotgun.cc:21: Unsupported feature selector for shotgun updater.
# Supported options are: {cyclic, shuffle}
#
# --------------------------------------------------------------------------------
# 7 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [00:25:34] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/linear/updater_shotgun.cc:21: Unsupported feature selector for shotgun updater.
# Supported options are: {cyclic, shuffle}
#
# --------------------------------------------------------------------------------
# 7 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [00:25:35] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/linear/updater_shotgun.cc:21: Unsupported feature selector for shotgun updater.
# Supported options are: {cyclic, shuffle}
#
# --------------------------------------------------------------------------------
# 7 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [00:25:36] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/linear/updater_shotgun.cc:21: Unsupported feature selector for shotgun updater.
# Supported options are: {cyclic, shuffle}
#
# --------------------------------------------------------------------------------
# 7 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [00:25:37] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/linear/updater_shotgun.cc:21: Unsupported feature selector for shotgun updater.
# Supported options are: {cyclic, shuffle}
#
# --------------------------------------------------------------------------------
# 7 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [00:25:38] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/linear/updater_shotgun.cc:21: Unsupported feature selector for shotgun updater.
# Supported options are: {cyclic, shuffle}
#
# --------------------------------------------------------------------------------
# 7 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [00:25:39] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/linear/updater_shotgun.cc:21: Unsupported feature selector for shotgun updater.
# Supported options are: {cyclic, shuffle}
#
# --------------------------------------------------------------------------------
# 7 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [00:25:40] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/linear/updater_shotgun.cc:21: Unsupported feature selector for shotgun updater.
# Supported options are: {cyclic, shuffle}
#
# --------------------------------------------------------------------------------
# 7 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
# ...
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [00:32:44] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/linear/updater_shotgun.cc:21: Unsupported feature selector for shotgun updater.
# Supported options are: {cyclic, shuffle}
#
# --------------------------------------------------------------------------------
# 8 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [00:32:45] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/linear/updater_shotgun.cc:21: Unsupported feature selector for shotgun updater.
# Supported options are: {cyclic, shuffle}
#
# --------------------------------------------------------------------------------
# 7 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [00:32:46] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/linear/updater_shotgun.cc:21: Unsupported feature selector for shotgun updater.
# Supported options are: {cyclic, shuffle}
#
# --------------------------------------------------------------------------------
# 8 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [00:32:47] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/linear/updater_shotgun.cc:21: Unsupported feature selector for shotgun updater.
# Supported options are: {cyclic, shuffle}
#
# --------------------------------------------------------------------------------
# 7 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [00:32:48] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/linear/updater_shotgun.cc:21: Unsupported feature selector for shotgun updater.
# Supported options are: {cyclic, shuffle}
#
# --------------------------------------------------------------------------------
# 7 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [00:32:49] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/linear/updater_shotgun.cc:21: Unsupported feature selector for shotgun updater.
# Supported options are: {cyclic, shuffle}
#
# --------------------------------------------------------------------------------
# 7 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [00:32:50] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/linear/updater_shotgun.cc:21: Unsupported feature selector for shotgun updater.
# Supported options are: {cyclic, shuffle}
#
# --------------------------------------------------------------------------------
# 8 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [00:32:51] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/linear/updater_shotgun.cc:21: Unsupported feature selector for shotgun updater.
# Supported options are: {cyclic, shuffle}
#
# --------------------------------------------------------------------------------
# 7 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [00:32:52] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/linear/updater_shotgun.cc:21: Unsupported feature selector for shotgun updater.
# Supported options are: {cyclic, shuffle}
#
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\sklearn.py", line 1516, in fit
#     self._Booster = train(
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 1918, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#   File "C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [00:32:53] C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/linear/updater_shotgun.cc:21: Unsupported feature selector for shotgun updater.
# Supported options are: {cyclic, shuffle}
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\AMGra\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_search.py:953: UserWarning: One or more of the test scores are non-finite: [0.9319486  0.93220571 0.93221961 0.9322891  0.93230299 0.91922505
#  0.91922505 0.91922505 0.91922505 0.91922505 0.91922505 0.91922505
#  0.91922505 0.91922505 0.91922505        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.91922505 0.91922505 0.91922505
#  0.91922505 0.91922505 0.91922505 0.91922505 0.91922505 0.91922505
#  0.91922505 0.91922505 0.91922505 0.91922505 0.91922505 0.91922505
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.91922505 0.91922505 0.91922505 0.91922505 0.91922505 0.91922505
#  0.91922505 0.91922505 0.91922505 0.91922505 0.91922505 0.91922505
#  0.91922505 0.91922505 0.91922505        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan]
#   warnings.warn(
# ----- XGBoost ----
# Accuracy : 0.9323169291065001
# f1 : 0.43582020389249304
# Testing
# Accuracy : 0.9345937866117239
# f1 : 0.4376519624869746

# %%
df = pd.DataFrame()
df['Feature'] = train.drop(columns=['ZZ_SPLIT','ZA_TARGET']).columns.to_list()
df['Coef'] = grid_logR.best_estimator_.coef_.tolist()[0]
df['Coef_abs'] = np.abs(df['Coef'])
df['Coef_odds'] = np.exp(df['Coef'])
df['Coef_prob'] = df['Coef'].apply(lambda x: np.exp(x)/(1+np.exp(x)))
df.sort_values(by='Coef_odds', ascending=False).head(5)
# Out:
#     Feature      Coef  Coef_abs  Coef_odds  Coef_prob
# 3      AHGA  4.293125  4.293125  73.194849   0.986522
# 0      AAGE  2.461090  2.461090  11.717576   0.921369
# 12  WKSWORK  1.863244  1.863244   6.444612   0.865675
# 5   CAPGAIN  1.133288  1.133288   3.105851   0.756445
# 6   CAPLOSS  1.068971  1.068971   2.912380   0.744401

# %%
df2 = pd.DataFrame()
df2['Feature'] = train.drop(columns=['ZZ_SPLIT','ZA_TARGET']).columns.to_list()
df2['Coef'] = grid_xg.best_estimator_.coef_.tolist()
df2['Coef_abs'] = df2['Coef'].apply(lambda x: np.abs(x))
df2['Coef_odds'] = df2['Coef'].apply(lambda x: np.exp(x))
df2['Coef_prob'] = df2['Coef'].apply(lambda x: np.exp(x)/(1+np.exp(x)))
df2.sort_values(by='Coef_odds', ascending=False).head(5)
# Out:
#     Feature     Coef  Coef_abs  Coef_odds  Coef_prob
# 3      AHGA  4.59835   4.59835  99.320302   0.990032
# 0      AAGE  2.73568   2.73568  15.420226   0.939099
# 12  WKSWORK  1.90952   1.90952   6.749848   0.870965
# 5   CAPGAIN  1.14659   1.14659   3.147442   0.758888
# 6   CAPLOSS  1.09426   1.09426   2.986972   0.749183

# %% [markdown]
# np.exp(12.47)
